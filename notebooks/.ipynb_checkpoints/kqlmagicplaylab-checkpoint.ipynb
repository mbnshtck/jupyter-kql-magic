# %% [markdown]
# # Kql Magic Demo

# %% [markdown]
# ### Kusto Banner

# %% [markdown]
# ![alt text](images/Kusto.jpg "Kusto Magic")

# %% [markdown]
# ### List current defined Magics
# *%kql and %%kql should not be listed*

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# ### Load KqlMagic
#
# *current load is from source code folder*
# *once KqlMagic will be public, will load from known repository *

# %%
# %pushd
# %cd C:\My Projects\KqlMagic\src
# %load_ext kql
# %popd
# Out:
# C:\My Projects\KqlMagic\src
# c:\My Projects\KqlMagic\notebooks
# popd -> c:\My Projects\KqlMagic\notebooks

# %% [markdown]
# ### List again current defined Magics
# *%kql and %%kql should be listed*

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %kql  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%kql  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# ### Configure KqlMagic DSN filename
# *Example how to configure KqlMagic properties*
# *when dsn_filename is set, KqlMagic can be instructed to get a section as a connection string*
#
# <font color='green'>bar</font>

# %% [markdown]
# <div class="alert alert-block alert-info">

# %%
# %config KqlMagic.dsn_filename = 'dsn/odbc.ini'

# %% [markdown]
# ### Get connection string to Kusto cluster from a section
# *Example how to get the connection string from a section*
# *to make it work, KqlMagic.dsn_filename must be set, and a section will connection string attributes must exist in the file *

# %%
# %kql [KUSTO-DSN]
# Out:
# kusto://username('michabin@microsoft.com').password('g=Hh-h34G').cluster('Oiildc').database('OperationInsights_PFS_PROD')
# 'Connected: OperationInsights_PFS_PROD@Oiildc'

# %% [markdown]
# ### Get connection string to Kusto cluster from an environment variable
# *Example how to get the connection string from an environment parameter*
# *to make it work, the environment variable must be set*

# %%
# %kql $HELP_CONNECTION_STR
# Out:
# 'Connected: Samples@help'

# %% [markdown]
# <div class="alert alert-block alert-info">Tip: Use blue boxes for Tips and notes. If it’s a note, you don’t have to include the word “Note”.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">Example: Use yellow boxes for examples that are not inside code cells, or use for mathematical formulas if needed.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">Up to you: Use green boxes sparingly, and only for some specific purpose that the other boxes can't cover. For example, if you have a lot of related content to link to, maybe you decide to use green boxes for related links from each section of a notebook. </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">Just don't: In general, just avoid the red boxes.</div>

# %% [markdown]
# <font color=blue|red|green|pink|yellow>Text</font> Not all markdown code works within a font tag, so review your colored text carefully!

# %% [markdown]
# # Set Kql results to raw

# %%
# %config KqlMagic.autopandas = False

# %% [markdown]
# # Enable matplotlib

# %%
# %matplotlib inline

# %% [markdown]
# # Kql query

# %%
# %kql
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# 'Connected: Samples@help'

# %%
# %%kql Samples@help
# PageViews | summarize count() by Language | sort by count_ | limit 10
# Out:
# Done (00:07.905): 10 records
# [<kql.kusto_proxy.KustoRow at 0x1f5dcee2a58>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2320>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2c50>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee22b0>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2240>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2dd8>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2b70>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2e48>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2e10>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2080>]

# %% [markdown]
# # Show last result - plot pie

# %%
_.pie();

# %% [markdown]
# # Show last results

# %%
_
# Out:
# [<kql.kusto_proxy.KustoRow at 0x1f5dcee2a58>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2320>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2c50>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee22b0>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2240>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2dd8>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2b70>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2e48>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2e10>,
#  <kql.kusto_proxy.KustoRow at 0x1f5dcee2080>]

# %% [markdown]
# # Kql - render barchart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# | sort by count_
# | limit 10
# | extend cs = 2 * count_
# | render barchart kind=stacked title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:01.891): 10 records

# %% [markdown]
# # Kql - render columnchart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# | sort by count_
# | limit 10
# | extend cs = 2 * count_
# //| extend cs3 = 0.6 * count_
# | render columnchart kind=stacked title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:01.870): 10 records

# %% [markdown]
# # Kql - render linechart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# //| sort by count_
# | limit 10
# | extend cs2 = 2 * count_
# | extend cs3 = 3 * count_
# //| extend cs4 = 4 * count_
# //| extend cs5 = count_ * count_
# | render linechart title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:01.980): 10 records
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="4f4dc732-c0b2-4a29-b7cc-e3372767edf3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4f4dc732-c0b2-4a29-b7cc-e3372767edf3", [{"type": "scatter", "x": [36, 54276, 95190, 347922, 507336, 1048386, 2804334, 14641824, 15137646, 16266774], "y": [72, 108552, 190380, 695844, 1014672, 2096772, 5608668, 29283648, 30275292, 32533548], "name": "cs2", "line": {"width": 1, "color": "rgb(184, 247, 212)"}, "opacity": 0.8}, {"type": "scatter", "x": [36, 54276, 95190, 347922, 507336, 1048386, 2804334, 14641824, 15137646, 16266774], "y": [108, 162828, 285570, 1043766, 1522008, 3145158, 8413002, 43925472, 45412938, 48800322], "name": "cs3", "line": {"width": 1, "color": "rgb(111, 231, 219)"}, "opacity": 0.8}], {"title": "Michael's chart", "showlegend": true, "xaxis": {"title": "count_"}, "yaxis": {"title": "cs2, cs3", "type": "linear"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# # Kql - render areachart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# //| sort by count_
# | limit 10
# | extend cs5 = 5 * count_
# | extend cs4 = 4 * count_
# | extend cs3 = 3 * count_
# | extend cs2 = 2 * count_
# | render areachart title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:01.927): 10 records
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="b78af73c-bbd3-4127-8fae-4591ba384afe" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b78af73c-bbd3-4127-8fae-4591ba384afe", [{"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [15137646, 14641824, 507336, 2804334, 1048386, 16266774, 95190, 347922, 36, 54276], "name": "count_", "mode": "lines", "line": {"width": 0.5, "color": "rgb(184, 247, 212)"}, "fill": "tozerox"}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [75688230, 73209120, 2536680, 14021670, 5241930, 81333870, 475950, 1739610, 180, 271380], "name": "cs5", "mode": "lines", "line": {"width": 0.5, "color": "rgb(111, 231, 219)"}, "fill": "tozerox"}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [60550584, 58567296, 2029344, 11217336, 4193544, 65067096, 380760, 1391688, 144, 217104], "name": "cs4", "mode": "lines", "line": {"width": 0.5, "color": "rgb(127, 166, 238)"}, "fill": "tozerox"}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [45412938, 43925472, 1522008, 8413002, 3145158, 48800322, 285570, 1043766, 108, 162828], "name": "cs3", "mode": "lines", "line": {"width": 0.5, "color": "rgb(131, 90, 241)"}, "fill": "tozerox"}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [30275292, 29283648, 1014672, 5608668, 2096772, 32533548, 190380, 695844, 72, 108552], "name": "cs2", "mode": "lines", "line": {"width": 0.5, "color": "rgb(184, 247, 212)"}, "fill": "tozerox"}], {"title": "Michael's chart", "showlegend": true, "xaxis": {"title": "Language", "type": "category"}, "yaxis": {"title": "count_, cs5, cs4, cs3, cs2", "type": "linear", "ticksuffix": ""}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# #