# %% [markdown]
# # Kql Magic Demo

# %% [markdown]
# ### Kusto Banner

# %% [markdown]
# ![alt text](images/Kusto.jpg "Kusto Magic")

# %% [markdown]
# ### List current defined Magics
# *%kql and %%kql should not be listed*

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# ### Load KqlMagic
#
# *current load is from source code folder*
# *once KqlMagic will be public, will load from known repository *

# %%
# %pushd
# %cd C:\My Projects\KqlMagic\src
# %load_ext kql
# %popd
# Out:
# C:\My Projects\KqlMagic\src
# c:\My Projects\KqlMagic\notebooks
# popd -> c:\My Projects\KqlMagic\notebooks

# %% [markdown]
# ### List again current defined Magics
# *%kql and %%kql should be listed*

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %kql  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%kql  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# ### Configure KqlMagic DSN filename
# *Example how to configure KqlMagic properties*
# *when dsn_filename is set, KqlMagic can be instructed to get a section as a connection string*
#
# <font color='green'>bar</font>

# %%
# %config KqlMagic.dsn_filename = 'dsn/odbc.ini'

# %% [markdown]
# ### Get connection string to Kusto cluster from a section
# *Example how to get the connection string from a section*
# *to make it work, KqlMagic.dsn_filename must be set, and a section will connection string attributes must exist in the file *

# %%
# %kql [KUSTO-DSN]
# Out:
# 'Connected: OperationInsights_PFS_PROD@Oiildc'

# %% [markdown]
# ### Get connection string to Kusto cluster from an environment variable
# *Example how to get the connection string from an environment parameter*
# *to make it work, the environment variable must be set*

# %%
# %kql
# Out:
#  * OperationInsights_PFS_PROD@Oiildc
# 'Connected: OperationInsights_PFS_PROD@Oiildc'

# %%
# %kql kusto://database('Samples')
# Out:
# 'Connected: Samples@Oiildc'

# %%
# %%kql kusto://database(yy)  gg
# Out:
# <div class="alert alert-block alert-danger">Cluster&nbspis&nbspnot&nbspdefined.</div>

# %%
# %kql $HELP_CONNECTION_STR
# Out:
# 'Connected: Samples@help'

# %% [markdown]
# <div class="alert alert-block alert-info">Tip: Use blue boxes for Tips and notes. If it’s a note, you don’t have to include the word “Note”.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">Example: Use yellow boxes for examples that are not inside code cells, or use for mathematical formulas if needed.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">Up to you: Use green boxes sparingly, and only for some specific purpose that the other boxes can't cover. For example, if you have a lot of related content to link to, maybe you decide to use green boxes for related links from each section of a notebook. </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">Just don't: In general, just avoid the red boxes.</div>

# %% [markdown]
# <font color=blue|red|green|pink|yellow>Text</font> Not all markdown code works within a font tag, so review your colored text carefully!

# %% [markdown]
# # Set Kql results to raw

# %%
# %config KqlMagic.autopandas = False

# %% [markdown]
# # Enable matplotlib

# %%
# %matplotlib inline

# %% [markdown]
# # Kql query

# %%
# %kql
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@Oiildc
#  * Samples@help
# 'Connected: Samples@help'

# %%
# %%kql Samples@help
# PageViews | summarize count() by Language | sort by count_ | limit 10
# Out:
# <div class="alert alert-block alert-success">Done&nbsp(00:06.150):&nbsp10&nbsprecords</div>
# [<kql.kusto_proxy.KustoRow at 0x2357a451390>,
#  <kql.kusto_proxy.KustoRow at 0x235024f5908>,
#  <kql.kusto_proxy.KustoRow at 0x235024f55c0>,
#  <kql.kusto_proxy.KustoRow at 0x235024f5358>,
#  <kql.kusto_proxy.KustoRow at 0x235024f5cf8>,
#  <kql.kusto_proxy.KustoRow at 0x235024f50b8>,
#  <kql.kusto_proxy.KustoRow at 0x235024f54e0>,
#  <kql.kusto_proxy.KustoRow at 0x235024f5d30>,
#  <kql.kusto_proxy.KustoRow at 0x235024f59b0>,
#  <kql.kusto_proxy.KustoRow at 0x235024f5ac8>]

# %%
_.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x235025d3d30>,
#   <matplotlib.patches.Wedge at 0x235025e0240>,
#   <matplotlib.patches.Wedge at 0x235025e0710>,
#   <matplotlib.patches.Wedge at 0x235025e0c18>,
#   <matplotlib.patches.Wedge at 0x235025eb198>,
#   <matplotlib.patches.Wedge at 0x235025eb6d8>,
#   <matplotlib.patches.Wedge at 0x235025ebc18>,
#   <matplotlib.patches.Wedge at 0x235025f3198>,
#   <matplotlib.patches.Wedge at 0x235025f36d8>,
#   <matplotlib.patches.Wedge at 0x235025f3c18>],
#  [Text(0.666033,0.875443,'en'),
#   Text(-0.993242,0.472725,'commons.m'),
#   Text(-0.35645,-1.04065,'de'),
#   Text(0.671951,-0.870908,'cs'),
#   Text(0.9095,-0.618716,'ar'),
#   Text(1.02311,-0.40404,'da'),
#   Text(1.06495,-0.275485,'ca'),
#   Text(1.08806,-0.161601,'bg'),
#   Text(1.09712,-0.0795336,'el'),
#   Text(1.09974,-0.0240109,'be')])

# %%
# %%kql Samples@help
# x << PageViews | summarize count() by Language | sort by count_ | limit 10
# Out:
# <div class="alert alert-block alert-success">Done&nbsp(00:02.000):&nbsp10&nbsprecords<br>Returning&nbspdata&nbspto&nbsplocal&nbspvariable&nbspx</div>

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %config InlineBackend.figure_format = 'retina'
x.pie();

# %%
# %kql PageViews | summarize count() by Language | sort by count_ | limit 10
_.pie()
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@Oiildc
#  * Samples@help
# <div class="alert alert-block alert-success">Done&nbsp(00:02.014):&nbsp10&nbsprecords</div>
# [<kql.kusto_proxy.KustoRow at 0x235025fbdd8>,
#  <kql.kusto_proxy.KustoRow at 0x235025fb668>,
#  <kql.kusto_proxy.KustoRow at 0x235025fbbe0>,
#  <kql.kusto_proxy.KustoRow at 0x235046b0f60>,
#  <kql.kusto_proxy.KustoRow at 0x235046b0f98>,
#  <kql.kusto_proxy.KustoRow at 0x235046b0fd0>,
#  <kql.kusto_proxy.KustoRow at 0x235046b0f28>,
#  <kql.kusto_proxy.KustoRow at 0x235046b03c8>,
#  <kql.kusto_proxy.KustoRow at 0x235046b0320>,
#  <kql.kusto_proxy.KustoRow at 0x235046b0940>]
# ([<matplotlib.patches.Wedge at 0x235056b2f98>,
#   <matplotlib.patches.Wedge at 0x235056bb4a8>,
#   <matplotlib.patches.Wedge at 0x235056bb9e8>,
#   <matplotlib.patches.Wedge at 0x235056bbf28>,
#   <matplotlib.patches.Wedge at 0x235056c44a8>,
#   <matplotlib.patches.Wedge at 0x235056c49e8>,
#   <matplotlib.patches.Wedge at 0x235056c4f28>,
#   <matplotlib.patches.Wedge at 0x235056cd4a8>,
#   <matplotlib.patches.Wedge at 0x235056cd9e8>,
#   <matplotlib.patches.Wedge at 0x235056cdf28>],
#  [Text(0.666033,0.875443,'en'),
#   Text(-0.993242,0.472725,'commons.m'),
#   Text(-0.35645,-1.04065,'de'),
#   Text(0.671951,-0.870908,'cs'),
#   Text(0.9095,-0.618716,'ar'),
#   Text(1.02311,-0.40404,'da'),
#   Text(1.06495,-0.275485,'ca'),
#   Text(1.08806,-0.161601,'bg'),
#   Text(1.09712,-0.0795336,'el'),
#   Text(1.09974,-0.0240109,'be')])

# %%
import pandas as pd
import numpy as np
import qgrid

# set the default max number of rows to 10 so the larger DataFrame we render don't take up to much space 
qgrid.set_grid_option('maxVisibleRows', 10)

df_scale = x.DataFrame()
# duplicate column B as a string column, to test scalability for text column filters
# df_scale['B (as str)'] = df_scale['B'].map(lambda x: str(x))
q_scale = qgrid.show_grid(df_scale, grid_options={'forceFitColumns': False, 'defaultColumnWidth': 200})
q_scale
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defaultColumnWidth': 200, 'rowHeight': 28, 'enableColumnReorder': False, 'enableTextSelectionOnCells': True, 'editable': True, 'autoEdit': False, 'explicitInitialization': True, 'maxVisibleRows': 10, 'minVisibleRows': 8, 'sortable': True, 'filterable': True, 'highlightSelectedCell': False, 'highlightSelectedRow': True}, precision=5)

# %%
import pandas as pd
import numpy as np
import qgrid

# set the default max number of rows to 10 so the larger DataFrame we render don't take up to much space 
qgrid.set_grid_option('maxVisibleRows', 10)

df_scale = x.DataFrame()
# duplicate column B as a string column, to test scalability for text column filters
# df_scale['B (as str)'] = df_scale['B'].map(lambda x: str(x))
q_scale = qgrid.show_grid(df_scale, grid_options={'forceFitColumns': False, 'defaultColumnWidth': 200})
q_scale
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defaultColumnWidth': 200, 'rowHeight': 28, 'enableColumnReorder': False, 'enableTextSelectionOnCells': True, 'editable': True, 'autoEdit': False, 'explicitInitialization': True, 'maxVisibleRows': 10, 'minVisibleRows': 8, 'sortable': True, 'filterable': True, 'highlightSelectedCell': False, 'highlightSelectedRow': True}, precision=5)

# %%
import pandas as pd
import numpy as np

rows = 2
columns = 4
df = pd.DataFrame(np.random.random(rows * columns).reshape(rows, columns))
pd.set_option('display.max_columns', columns)
pd.set_option('display.max_rows', rows)
df
# Out:
#           0         1         2         3
# 0  0.820653  0.495359  0.959396  0.488701
# 1  0.550318  0.177128  0.797138  0.693465

# %% [markdown]
# # Show last result - plot pie

# %% [markdown]
# # Show last results

# %%
_
# Out:
#           0         1         2         3
# 0  0.820653  0.495359  0.959396  0.488701
# 1  0.550318  0.177128  0.797138  0.693465

# %% [markdown]
# # Kql - render barchart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# | sort by count_
# | limit 10
# | extend cs = 2 * count_
# | render barchart kind=stacked title="Michael's chart";
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@Oiildc
#  * Samples@help
# <div class="alert alert-block alert-success">Done&nbsp(00:02.128):&nbsp10&nbsprecords</div>

# %%
print("aaa")
# %kql PageViews | summarize count() by Language | sort by count_ | limit 10 | extend cs = 2 * count_ | render barchart kind=stacked title="Michael's chart";
# %kql PageViews | summarize count() by Language | sort by count_ | limit 10 | extend cs = 2 * count_ | render barchart kind=stacked title="Michael's chart";
# Out:
# aaa
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@Oiildc
#  * Samples@help
# <div class="alert alert-block alert-success">Done&nbsp(00:01.948):&nbsp10&nbsprecords</div>
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@Oiildc
#  * Samples@help
# <div class="alert alert-block alert-success">Done&nbsp(00:01.924):&nbsp10&nbsprecords</div>

# %% [markdown]
# # Kql - render columnchart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# | sort by count_
# | limit 10
# | extend cs = 2 * count_
# //| extend cs3 = 0.6 * count_
# | render columnchart kind=stacked title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@Oiildc
#  * Samples@help
# <div class="alert alert-block alert-success">Done&nbsp(00:01.994):&nbsp10&nbsprecords</div>

# %% [markdown]
# # Kql - render linechart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# //| sort by count_
# | limit 10
# | extend cs2 = 2 * count_
# | extend cs3 = 3 * count_
# //| extend cs4 = 4 * count_
# //| extend cs5 = count_ * count_
# | render linechart title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@Oiildc
#  * Samples@help
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="ac9e9d1d-cefa-4fa6-9af0-bc2614dc7832" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ac9e9d1d-cefa-4fa6-9af0-bc2614dc7832", [{"type": "scatter", "x": [36, 54276, 95190, 347922, 507336, 1048386, 2804334, 14641824, 15137646, 16266774], "y": [72, 108552, 190380, 695844, 1014672, 2096772, 5608668, 29283648, 30275292, 32533548], "name": "cs2", "line": {"width": 1, "color": "rgb(184, 247, 212)"}, "opacity": 0.8}, {"type": "scatter", "x": [36, 54276, 95190, 347922, 507336, 1048386, 2804334, 14641824, 15137646, 16266774], "y": [108, 162828, 285570, 1043766, 1522008, 3145158, 8413002, 43925472, 45412938, 48800322], "name": "cs3", "line": {"width": 1, "color": "rgb(111, 231, 219)"}, "opacity": 0.8}], {"title": "Michael's chart", "showlegend": true, "xaxis": {"title": "count_"}, "yaxis": {"title": "cs2, cs3", "type": "linear"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div class="alert alert-block alert-success">Done&nbsp(00:01.941):&nbsp10&nbsprecords</div>

# %%
# %kql PageViews | summarize count() by Language | limit 10 | extend cs2 = 2 * count_ | extend cs3 = 3 * count_ | render linechart title="Michael's chart"
#%kql PageViews | summarize count() by Language | limit 10 | extend cs2 = 2 * count_ | extend cs3 = 3 * count_ | render linechart title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@Oiildc
#  * Samples@help
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="cd9b9334-6b6f-4474-9f98-794477fdc4ef" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cd9b9334-6b6f-4474-9f98-794477fdc4ef", [{"type": "scatter", "x": [36, 54276, 95190, 347922, 507336, 1048386, 2804334, 14641824, 15137646, 16266774], "y": [72, 108552, 190380, 695844, 1014672, 2096772, 5608668, 29283648, 30275292, 32533548], "name": "cs2", "line": {"width": 1, "color": "rgb(184, 247, 212)"}, "opacity": 0.8}, {"type": "scatter", "x": [36, 54276, 95190, 347922, 507336, 1048386, 2804334, 14641824, 15137646, 16266774], "y": [108, 162828, 285570, 1043766, 1522008, 3145158, 8413002, 43925472, 45412938, 48800322], "name": "cs3", "line": {"width": 1, "color": "rgb(111, 231, 219)"}, "opacity": 0.8}], {"title": "Michael's chart", "showlegend": true, "xaxis": {"title": "count_"}, "yaxis": {"title": "cs2, cs3", "type": "linear"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div class="alert alert-block alert-success">Done&nbsp(00:01.944):&nbsp10&nbsprecords</div>

# %% [markdown]
# # Kql - render areachart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# //| sort by count_
# | limit 10
# | extend cs5 = 5 * count_
# | extend cs4 = 4 * count_
# | extend cs3 = 3 * count_
# | extend cs2 = 2 * count_
# | render areachart title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@Oiildc
#  * Samples@help
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="00be00a7-f6f9-4dd3-8da7-ef11039b3ad6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("00be00a7-f6f9-4dd3-8da7-ef11039b3ad6", [{"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [15137646, 14641824, 507336, 2804334, 1048386, 16266774, 95190, 347922, 36, 54276], "name": "count_", "mode": "lines", "line": {"width": 0.5, "color": "rgb(184, 247, 212)"}, "fill": "tozerox"}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [75688230, 73209120, 2536680, 14021670, 5241930, 81333870, 475950, 1739610, 180, 271380], "name": "cs5", "mode": "lines", "line": {"width": 0.5, "color": "rgb(111, 231, 219)"}, "fill": "tozerox"}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [60550584, 58567296, 2029344, 11217336, 4193544, 65067096, 380760, 1391688, 144, 217104], "name": "cs4", "mode": "lines", "line": {"width": 0.5, "color": "rgb(127, 166, 238)"}, "fill": "tozerox"}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [45412938, 43925472, 1522008, 8413002, 3145158, 48800322, 285570, 1043766, 108, 162828], "name": "cs3", "mode": "lines", "line": {"width": 0.5, "color": "rgb(131, 90, 241)"}, "fill": "tozerox"}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [30275292, 29283648, 1014672, 5608668, 2096772, 32533548, 190380, 695844, 72, 108552], "name": "cs2", "mode": "lines", "line": {"width": 0.5, "color": "rgb(184, 247, 212)"}, "fill": "tozerox"}], {"title": "Michael's chart", "showlegend": true, "xaxis": {"title": "Language", "type": "category"}, "yaxis": {"title": "count_, cs5, cs4, cs3, cs2", "type": "linear", "ticksuffix": ""}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div class="alert alert-block alert-success">Done&nbsp(00:02.034):&nbsp10&nbsprecords</div>

# %% [markdown]
# # Kql - render scatterchart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# //| sort by count_
# | limit 10
# | extend cs5 = count_ * 5
# | extend cs4 = count_ * 4
# | extend cs3 = count_ * 3
# | extend cs2 = count_ * 2
# | render scatterchart title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@Oiildc
#  * Samples@help
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="b7c7b8b4-aa2d-4311-a21a-353d08e1cfd7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b7c7b8b4-aa2d-4311-a21a-353d08e1cfd7", [{"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [15137646, 14641824, 507336, 2804334, 1048386, 16266774, 95190, 347922, 36, 54276], "name": "count_", "mode": "markers", "marker": {"line": {"width": 1}, "color": "rgb(184, 247, 212)"}}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [75688230, 73209120, 2536680, 14021670, 5241930, 81333870, 475950, 1739610, 180, 271380], "name": "cs5", "mode": "markers", "marker": {"line": {"width": 1}, "color": "rgb(111, 231, 219)"}}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [60550584, 58567296, 2029344, 11217336, 4193544, 65067096, 380760, 1391688, 144, 217104], "name": "cs4", "mode": "markers", "marker": {"line": {"width": 1}, "color": "rgb(127, 166, 238)"}}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [45412938, 43925472, 1522008, 8413002, 3145158, 48800322, 285570, 1043766, 108, 162828], "name": "cs3", "mode": "markers", "marker": {"line": {"width": 1}, "color": "rgb(131, 90, 241)"}}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [30275292, 29283648, 1014672, 5608668, 2096772, 32533548, 190380, 695844, 72, 108552], "name": "cs2", "mode": "markers", "marker": {"line": {"width": 1}, "color": "rgb
211408616693828, 1.214839565187829, 1.2177459832086124, 1.2200325775721046, 1.2240355512181789, 1.2285003065785869, 1.2301188874237377, 1.2302782202700902, 1.2306333147210158, 1.2309561992484845, 1.235389086462734, 1.2357841687192386, 1.239360732725789, 1.240262803640374, 1.243575516761334, 1.257591534039524, 1.2584797133998689, 1.2600039027948313, 1.2623772404461273, 1.2690656783255387, 1.2702071091996678, 1.278652645701744, 1.286728281454376, 1.2970749539147128, 1.3003983746992769, 1.3017288973201673, 1.3035543615599599, 1.3109513751380626, 1.3120777321223829, 1.3131658132712918, 1.3189551423831798, 1.325996873886337, 1.327717501134726, 1.328023370287371, 1.3282791782731933, 1.3338403850294849, 1.3360012188475638, 1.340611394144781, 1.3549487685658606, 1.3651134620961665, 1.373591763499095, 1.3944355753033724, 1.3981775921043211, 1.4039168286497938, 1.4047236647421768, 1.4080928206762438, 1.4107049076072546, 1.41992346969573, 1.420515765706071, 1.4259342687308438, 1.429378558951096, 1.4323765991717714, 1.442317884317143, 1.4467659278653149, 1.4519525075382274, 1.4521373460779823, 1.461898429948865, 1.4707095584320293, 1.4708105076256173, 1.4708662448018925, 1.4818999674720477, 1.48317309032214, 1.4878048156689074, 1.4896441154474618, 1.4911009845696879, 1.5022120741239615, 1.503724703008928, 1.5045895912219573, 1.5065695291957948, 1.506898020824833, 1.507718302216742, 1.513147711898995, 1.5136840137772212, 1.515544436599101, 1.5206638552133902, 1.5281184583523362, 1.5 ...
# <div class="alert alert-block alert-success">Done&nbsp(00:01.108):&nbsp375&nbsprecords</div>

# %% [markdown]
# # Kql - render anomalychart

# %%
# %%kql
# let randn = () {rand() + rand() + rand()};
# range columnName from datetime('2015-01-01') to datetime('2016-01-10') step 1d
# | extend e1 = randn()
# | extend e2 = randn()
# | extend e3 = randn()
# | extend e4 = randn()
# | render anomalychart title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@Oiildc
#  * Samples@help
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="c3943f0d-3882-4707-82af-5de968b5f10b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c3943f0d-3882-4707-82af-5de968b5f10b", [{"type": "scatter", "x": ["2015-01-01", "2015-01-02", "2015-01-03", "2015-01-04", "2015-01-05", "2015-01-06", "2015-01-07", "2015-01-08", "2015-01-09", "2015-01-10", "2015-01-11", "2015-01-12", "2015-01-13", "2015-01-14", "2015-01-15", "2015-01-16", "2015-01-17", "2015-01-18", "2015-01-19", "2015-01-20", "2015-01-21", "2015-01-22", "2015-01-23", "2015-01-24", "2015-01-25", "2015-01-26", "2015-01-27", "2015-01-28", "2015-01-29", "2015-01-30", "2015-01-31", "2015-02-01", "2015-02-02", "2015-02-03", "2015-02-04", "2015-02-05", "2015-02-06", "2015-02-07", "2015-02-08", "2015-02-09", "2015-02-10", "2015-02-11", "2015-02-12", "2015-02-13", "2015-02-14", "2015-02-15", "2015-02-16", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-21", "2015-02-22", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-02-28", "2015-03-01", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-07", "2015-03-08", "2015-03-09", "2015-03-10", "2015-03-11", "2015-03-12", "2015-03-13", "2015-03-14", "2015-03-15", "2015-03-16", "2015-03-17", "2015-03-18", "2015-03-19", "2015-03-20", "2015-03-21", "2015-03-22", "2015-03-23", "2015-03-24", "2015-03-25", "2015-03-26", "2015-03-27", "2015-03-28", "2015-03-29", "2015-03-30", "2015-03-31", "2015-04-01", "2015-04-02", "2015-04-03", "2015-04-04", "2015-04-05", "2015-04-06", "2015-04-07", "2015-04-08", "2015-04-09", "2015-04-10", "2015-04-11", "2015-04-12", "2015-04-13", "2015-04-14", "2015-04-15", "2015-04-16", "2015-04-17", "2015-04-18", "2015-04-19", "2015-04-20", "2015-04-21", "2015-04-22", "2015-04-23", "2015-04-24", "2015-04-25", "2015-04-26", "2015-04-27", "2015-04-28", "2015-04-29", "2015-04-30", "2015-05-01", "2015-05-02", "2015-05-03", "2015-05-04", "2015-05-05", "2015-05-06", "2015-05-07", "2015-05-08", "2015-05-09", "2015-05-10", "2015-05-11", "2015-05-12", "2015-05-13", "2015-05-14", "2015-05-15", "2015-05-16", "2015-05-17", "2015-05-18", "2015-05-19", "2015-05-20", "2015-05-21", "2015-05-22", "2015-05-23", "2015-05-24", "2015-05-25", "2015-05-26", "2015-05-27", "2015-05-28", "2015-05-29", "2015-05-30", "2015-05-31", "2015-06-01", "2015-06-02", "2015-06-03", "2015-06-04", "2015-06-05", "2015-06-06", "2015-06-07", "2015-06-08", "2015-06-09", "2015-06-10", "2015-06-11", "2015-06-12", "2015-06-13", "2015-06-14", "2015-06-15", "2015-06-16", "2015-06-17", "2015-06-18", "2015-06-19", "2015-06-20", "2015-06-21", "2015-06-22", "2015-06-23", "2015-06-24", "2015-06-25", "2015-06-26", "2015-06-27", "2015-06-28", "2015-06-29", "2015-06-30", "2015-07-01", "2015-07-02", "2015-07-03", "2015-07-04", "2015-07-05", "2015-07-06", "2015-07-07", "2015-07-08", "2015-07-09", "2015-07-10", "2015-07-11", "2015-07-12", "2015-07-13", "2015-07-14", "2015-07-15", "2015-07-16", "2015-07-17", "2015-07-18", "2015-07-19", "2015-07-20", "2015-07-21", "2015-07-22", "2015-07-23", "2015-07-24", "2015-07-25", "2015-07-26", "2015-07-27", "2015-07-28", "2015-07-29", "2015-07-30", "2015-07-31", "2015-08-01", "2015-08-02", "2015-08-03", "2015-08-04", "2015-08-05", "2015-08-06", "2015-08-07", "2015-08-08", "2015-08-09", "2015-08-10", "2015-08-11", "2015-08-12", "2015-08-13", "2015-08-14", "2015-08-15", "2015-08-16", "2015-08-17", "2015-08-18", "2015-08-19", "2015-08-20", "2015-08-21", "2015-08-22", "2015-08-23", "2015-08-24", "2015-08-25", "2015-08-26", "2015-08-27", "2015-08-28", "2015-08-29", "2015-08-30", "2015-08-31", "2015-09-01", "2015-09-02", "2015-09-03", "2015-09-04", "2015-09-05", "2015-09-06", "2015-09-07", "2015-09-08", "2015-09-09", "2015-09-10", "2015-09-11", "2015-09-12", "2015-09-13", "2015-09-14", "2015-09-15", "2015-09-16", "2015-09-17", "2015-09-1 ...
# <div class="alert alert-block alert-success">Done&nbsp(00:00.999):&nbsp375&nbsprecords</div>

# %%
name = input("what is your name: ")
print("name: ", name)
name = input("what is your name: ")
print("name: ", name)
name = input("what is your name: ")
print("name: ", name)

# %%
import getpass
p = getpass.getpass()

# %%
print(p)

# %%
import ipywidgets as widgets
from IPython.display import display
x = 12
w = widgets.IntSlider(x)
display(w)
# Out:
# IntSlider(value=12)

# %%
display(w)
display(w)
display(w)
# Out:
# IntSlider(value=12)
# IntSlider(value=12)
# IntSlider(value=12)

# %%
w.value

# %%
p = getpass.getpass()
p = getpass.getpass()
p = getpass.getpass()

# %%
# %pushd
# %cd C:\My Projects\KqlMagic\src
# %load_ext kql
# %popd
# Out:
# ['c:\\My Projects\\KqlMagic\\notebooks']
# C:\My Projects\KqlMagic\src
# The kql extension is already loaded. To reload it, use:
#   %reload_ext kql
# c:\My Projects\KqlMagic\notebooks
# popd -> c:\My Projects\KqlMagic\notebooks

# %%
# %kql appinsights://appid('DEMO_APP').appkey('DEMO_KEY')
# Out:
# 'Connected: DEMO_APP@appinsights'

# %%
# %kql kusto://
# Out:
# <div class="alert alert-block alert-danger">Invalid&nbspconnection&nbspstring.</div>
# <div class="alert alert-block alert-info">Connection&nbspinfo&nbspneeded&nbspin&nbspKQL&nbspMagic&nbspformat,&nbspexample:<br>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbspkusto://username('username').password('password').cluster('clustername').database('databasename')<br>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbspkusto://username('username').password('password').cluster('clustername')<br>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbspkusto://username('username').password('password')<br>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbspkusto://cluster('clustername').database('databasename')<br>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbspkusto://cluster('clustername')<br>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbspkusto://database('databasename')<br>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbspor&nbspan&nbspexisting&nbspconnection:&nbsp['OperationInsights_PFS_PROD@Oiildc',&nbsp'Samples@Oiildc',&nbsp'Samples@help']<br>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp</div>

# %%
# %kql appinsights://
# Out:
# <div class="alert alert-block alert-danger">Invalid&nbspconnection&nbspstring.</div>
# <div class="alert alert-block alert-info">Connection&nbspinfo&nbspneeded&nbspin&nbspKQL&nbspMagic&nbspformat,&nbspexample:<br>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbspappinsights://appid('appid').appkey('appkey')<br>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbspor&nbspan&nbspexisting&nbspconnection:&nbsp['DEMO_APP@appinsights']<br>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp</div>

# %%
# %%kql
# let randn = () {rand() + rand() + rand()};
# range columnName from datetime('2015-01-01') to datetime('2016-01-10') step 1d
# | extend e1 = randn()
# | extend e2 = randn()
# | extend e3 = randn()
# | extend e4 = randn()
# | render anomalychart title="Michael's chart"
# Out:
#  * DEMO_APP@appinsights
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@Oiildc
#    Samples@help
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="fe61e2e9-6681-4dd0-a175-81227b027af7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fe61e2e9-6681-4dd0-a175-81227b027af7", [{"type": "scatter", "x": ["2015-01-01", "2015-01-02", "2015-01-03", "2015-01-04", "2015-01-05", "2015-01-06", "2015-01-07", "2015-01-08", "2015-01-09", "2015-01-10", "2015-01-11", "2015-01-12", "2015-01-13", "2015-01-14", "2015-01-15", "2015-01-16", "2015-01-17", "2015-01-18", "2015-01-19", "2015-01-20", "2015-01-21", "2015-01-22", "2015-01-23", "2015-01-24", "2015-01-25", "2015-01-26", "2015-01-27", "2015-01-28", "2015-01-29", "2015-01-30", "2015-01-31", "2015-02-01", "2015-02-02", "2015-02-03", "2015-02-04", "2015-02-05", "2015-02-06", "2015-02-07", "2015-02-08", "2015-02-09", "2015-02-10", "2015-02-11", "2015-02-12", "2015-02-13", "2015-02-14", "2015-02-15", "2015-02-16", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-21", "2015-02-22", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-02-28", "2015-03-01", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-07", "2015-03-08", "2015-03-09", "2015-03-10", "2015-03-11", "2015-03-12", "2015-03-13", "2015-03-14", "2015-03-15", "2015-03-16", "2015-03-17", "2015-03-18", "2015-03-19", "2015-03-20", "2015-03-21", "2015-03-22", "2015-03-23", "2015-03-24", "2015-03-25", "2015-03-26", "2015-03-27", "2015-03-28", "2015-03-29", "2015-03-30", "2015-03-31", "2015-04-01", "2015-04-02", "2015-04-03", "2015-04-04", "2015-04-05", "2015-04-06", "2015-04-07", "2015-04-08", "2015-04-09", "2015-04-10", "2015-04-11", "2015-04-12", "2015-04-13", "2015-04-14", "2015-04-15", "2015-04-16", "2015-04-17", "2015-04-18", "2015-04-19", "2015-04-20", "2015-04-21", "2015-04-22", "2015-04-23", "2015-04-24", "2015-04-25", "2015-04-26", "2015-04-27", "2015-04-28", "2015-04-29", "2015-04-30", "2015-05-01", "2015-05-02", "2015-05-03", "2015-05-04", "2015-05-05", "2015-05-06", "2015-05-07", "2015-05-08", "2015-05-09", "2015-05-10", "2015-05-11", "2015-05-12", "2015-05-13", "2015-05-14", "2015-05-15", "2015-05-16", "2015-05-17", "2015-05-18", "2015-05-19", "2015-05-20", "2015-05-21", "2015-05-22", "2015-05-23", "2015-05-24", "2015-05-25", "2015-05-26", "2015-05-27", "2015-05-28", "2015-05-29", "2015-05-30", "2015-05-31", "2015-06-01", "2015-06-02", "2015-06-03", "2015-06-04", "2015-06-05", "2015-06-06", "2015-06-07", "2015-06-08", "2015-06-09", "2015-06-10", "2015-06-11", "2015-06-12", "2015-06-13", "2015-06-14", "2015-06-15", "2015-06-16", "2015-06-17", "2015-06-18", "2015-06-19", "2015-06-20", "2015-06-21", "2015-06-22", "2015-06-23", "2015-06-24", "2015-06-25", "2015-06-26", "2015-06-27", "2015-06-28", "2015-06-29", "2015-06-30", "2015-07-01", "2015-07-02", "2015-07-03", "2015-07-04", "2015-07-05", "2015-07-06", "2015-07-07", "2015-07-08", "2015-07-09", "2015-07-10", "2015-07-11", "2015-07-12", "2015-07-13", "2015-07-14", "2015-07-15", "2015-07-16", "2015-07-17", "2015-07-18", "2015-07-19", "2015-07-20", "2015-07-21", "2015-07-22", "2015-07-23", "2015-07-24", "2015-07-25", "2015-07-26", "2015-07-27", "2015-07-28", "2015-07-29", "2015-07-30", "2015-07-31", "2015-08-01", "2015-08-02", "2015-08-03", "2015-08-04", "2015-08-05", "2015-08-06", "2015-08-07", "2015-08-08", "2015-08-09", "2015-08-10", "2015-08-11", "2015-08-12", "2015-08-13", "2015-08-14", "2015-08-15", "2015-08-16", "2015-08-17", "2015-08-18", "2015-08-19", "2015-08-20", "2015-08-21", "2015-08-22", "2015-08-23", "2015-08-24", "2015-08-25", "2015-08-26", "2015-08-27", "2015-08-28", "2015-08-29", "2015-08-30", "2015-08-31", "2015-09-01", "2015-09-02", "2015-09-03", "2015-09-04", "2015-09-05", "2015-09-06", "2015-09-07", "2015-09-08", "2015-09-09", "2015-09-10", "2015-09-11", "2015-09-12", "2015-09-13", "2015-09-14", "2015-09-15", "2015-09-16", "2015-09-17", "2015-09-1 ...
# <div class="alert alert-block alert-success">Done&nbsp(00:01.405):&nbsp375&nbsprecords</div>

# %%
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

table = ff.create_table(df)
plotly.offline.iplot(table, filename='jupyter/table1')
# Out:
# <div id="b0eaa985-c605-44af-a866-7d56f66ce36c" style="height: 710px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b0eaa985-c605-44af-a866-7d56f66ce36c", [{"type": "heatmap", "z": [[0, 0, 0, 0], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5]], "opacity": 0.75, "colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]], "showscale": false, "hoverinfo": "none"}], {"annotations": [{"text": "<b>School</b>", "x": -0.45, "y": 0, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#ffffff"}, "showarrow": false}, {"text": "<b>Women</b>", "x": 0.55, "y": 0, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#ffffff"}, "showarrow": false}, {"text": "<b>Men</b>", "x": 1.55, "y": 0, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#ffffff"}, "showarrow": false}, {"text": "<b>Gap</b>", "x": 2.55, "y": 0, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#ffffff"}, "showarrow": false}, {"text": "MIT", "x": -0.45, "y": 1, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "94", "x": 0.55, "y": 1, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "152", "x": 1.55, "y": 1, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "58", "x": 2.55, "y": 1, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "Stanford", "x": -0.45, "y": 2, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "96", "x": 0.55, "y": 2, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "151", "x": 1.55, "y": 2, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "55", "x": 2.55, "y": 2, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "Harvard", "x": -0.45, "y": 3, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "112", "x": 0.55, "y": 3, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "165", "x": 1.55, "y": 3, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "53", "x": 2.55, "y": 3, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "U.Penn", "x": -0.45, "y": 4, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "92", "x": 0.55, "y": 4, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "141", "x": 1.55, "y": 4, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "49", "x": 2.55, "y": 4, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "Princeton", "x": -0.45, "y": 5, "xref": "x1", "yref": "y1 ...
