# %% [markdown]
# # Kql Magic Demo

# %% [markdown]
# ### Kusto Banner

# %% [markdown]
# ![alt text](images/Kusto.jpg "Kusto Magic")

# %% [markdown]
# ### List current defined Magics
# *%kql and %%kql should not be listed*

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# ### Load KqlMagic
#
# *current load is from source code folder*
# *once KqlMagic will be public, will load from known repository *

# %%
# %pushd
# %cd C:\My Projects\KqlMagic\src
# %load_ext kql
# %popd
# Out:
# C:\My Projects\KqlMagic\src
# c:\My Projects\KqlMagic\notebooks
# popd -> c:\My Projects\KqlMagic\notebooks

# %% [markdown]
# ### List again current defined Magics
# *%kql and %%kql should be listed*

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %kql  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%kql  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# ### Configure KqlMagic DSN filename
# *Example how to configure KqlMagic properties*
# *when dsn_filename is set, KqlMagic can be instructed to get a section as a connection string*
#
# <font color='green'>bar</font>

# %%
# %config KqlMagic.dsn_filename = 'dsn/odbc.ini'

# %% [markdown]
# ### Get connection string to Kusto cluster from a section
# *Example how to get the connection string from a section*
# *to make it work, KqlMagic.dsn_filename must be set, and a section will connection string attributes must exist in the file *

# %%
# %kql [KUSTO-DSN]
# Out:
# kusto://username('michabin@microsoft.com').password('g=Hh-h34G').cluster('Oiildc').database('OperationInsights_PFS_PROD')
# 'Connected: OperationInsights_PFS_PROD@Oiildc'

# %% [markdown]
# ### Get connection string to Kusto cluster from an environment variable
# *Example how to get the connection string from an environment parameter*
# *to make it work, the environment variable must be set*

# %%
# %kql $HELP_CONNECTION_STR
# Out:
# 'Connected: Samples@help'

# %% [markdown]
# <div class="alert alert-block alert-info">Tip: Use blue boxes for Tips and notes. If it’s a note, you don’t have to include the word “Note”.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">Example: Use yellow boxes for examples that are not inside code cells, or use for mathematical formulas if needed.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">Up to you: Use green boxes sparingly, and only for some specific purpose that the other boxes can't cover. For example, if you have a lot of related content to link to, maybe you decide to use green boxes for related links from each section of a notebook. </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">Just don't: In general, just avoid the red boxes.</div>

# %% [markdown]
# <font color=blue|red|green|pink|yellow>Text</font> Not all markdown code works within a font tag, so review your colored text carefully!

# %% [markdown]
# # Set Kql results to raw

# %%
# %config KqlMagic.autopandas = False

# %% [markdown]
# # Enable matplotlib

# %%
# %matplotlib inline

# %% [markdown]
# # Kql query

# %%
# %kql
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# 'Connected: Samples@help'

# %%
# %%kql Samples@help
# PageViews | summarize count() by Language | sort by count_ | limit 10
# Out:
# Done (00:02.182): 10 records
# [<kql.kusto_proxy.KustoRow at 0x1cc0a58c320>,
#  <kql.kusto_proxy.KustoRow at 0x1cc0a58c358>,
#  <kql.kusto_proxy.KustoRow at 0x1cc0a58c048>,
#  <kql.kusto_proxy.KustoRow at 0x1cc0a58c860>,
#  <kql.kusto_proxy.KustoRow at 0x1cc0a58c940>,
#  <kql.kusto_proxy.KustoRow at 0x1cc0a58ca58>,
#  <kql.kusto_proxy.KustoRow at 0x1cc0a58c7b8>,
#  <kql.kusto_proxy.KustoRow at 0x1cc0a5881d0>,
#  <kql.kusto_proxy.KustoRow at 0x1cc0a5882b0>,
#  <kql.kusto_proxy.KustoRow at 0x1cc0a588208>]

# %%
# %%kql Samples@help
# x << PageViews | summarize count() by Language | sort by count_ | limit 10
# Out:
# Done (00:02.239): 10 records
# Returning data to local variable x

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
.interactiveshell import Intera
ast_node_interactivity = "all"

# %%
# %config InlineBackend.figure_format = 'retina'
x.pie();

# %%
import pandas as pd
import numpy as np
import qgrid

# set the default max number of rows to 10 so the larger DataFrame we render don't take up to much space 
qgrid.set_grid_option('maxVisibleRows', 10)

df_scale = x.DataFrame()
# duplicate column B as a string column, to test scalability for text column filters
# df_scale['B (as str)'] = df_scale['B'].map(lambda x: str(x))
q_scale = qgrid.show_grid(df_scale, grid_options={'forceFitColumns': False, 'defaultColumnWidth': 200})
q_scale
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defaultColumnWidth': 200, 'rowHeight': 28, 'enableColumnReorder': False, 'enableTextSelectionOnCells': True, 'editable': True, 'autoEdit': False, 'explicitInitialization': True, 'maxVisibleRows': 10, 'minVisibleRows': 8}, precision=5)

# %%
import pandas as pd
import numpy as np
import qgrid

# set the default max number of rows to 10 so the larger DataFrame we render don't take up to much space 
qgrid.set_grid_option('maxVisibleRows', 10)

df_scale = x.DataFrame()
# duplicate column B as a string column, to test scalability for text column filters
# df_scale['B (as str)'] = df_scale['B'].map(lambda x: str(x))
q_scale = qgrid.show_grid(df_scale, grid_options={'forceFitColumns': False, 'defaultColumnWidth': 200})
q_scale
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defaultColumnWidth': 200, 'rowHeight': 28, 'enableColumnReorder': False, 'enableTextSelectionOnCells': True, 'editable': True, 'autoEdit': False, 'explicitInitialization': True, 'maxVisibleRows': 10, 'minVisibleRows': 8}, precision=5)

# %%
import pandas as pd
import numpy as np

rows = 2
columns = 4
df = pd.DataFrame(np.random.random(rows * columns).reshape(rows, columns))
pd.set_option('display.max_columns', columns)
pd.set_option('display.max_rows', rows)
df
# Out:
#           0         1         2         3
# 0  0.509877  0.524470  0.656402  0.482118
# 1  0.155322  0.523831  0.326244  0.989535

# %%
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff

# df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

table = ff.create_table(df)
plotly.offline.iplot(table, filename='jupyter/table1')
# Out:
# <div id="ee1f547a-e6f3-4976-9fd5-9fd7c78193fc" style="height: 140px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ee1f547a-e6f3-4976-9fd5-9fd7c78193fc", [{"type": "heatmap", "z": [[0, 0, 0, 0], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1]], "opacity": 0.75, "colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]], "showscale": false, "hoverinfo": "none"}], {"annotations": [{"text": "<b>0</b>", "x": -0.45, "y": 0, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#ffffff"}, "showarrow": false}, {"text": "<b>1</b>", "x": 0.55, "y": 0, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#ffffff"}, "showarrow": false}, {"text": "<b>2</b>", "x": 1.55, "y": 0, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#ffffff"}, "showarrow": false}, {"text": "<b>3</b>", "x": 2.55, "y": 0, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#ffffff"}, "showarrow": false}, {"text": "0.5098768129451526", "x": -0.45, "y": 1, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "0.5244703710371416", "x": 0.55, "y": 1, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "0.6564016693917989", "x": 1.55, "y": 1, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "0.48211826887842135", "x": 2.55, "y": 1, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "0.15532248531715565", "x": -0.45, "y": 2, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "0.5238308002855117", "x": 0.55, "y": 2, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "0.3262441861339128", "x": 1.55, "y": 2, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}, {"text": "0.9895349543839452", "x": 2.55, "y": 2, "xref": "x1", "yref": "y1", "align": "left", "xanchor": "left", "font": {"color": "#000000"}, "showarrow": false}], "height": 140, "margin": {"t": 0, "b": 0, "r": 0, "l": 0}, "yaxis": {"autorange": "reversed", "zeroline": false, "gridwidth": 2, "ticks": "", "dtick": 1, "tick0": 0.5, "showticklabels": false}, "xaxis": {"zeroline": false, "gridwidth": 2, "ticks": "", "dtick": 1, "tick0": -0.5, "showticklabels": false}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# # Show last result - plot pie

# %%
_.pie();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-a352be7d4f4e> in <module>()
# ----> 1 _.pie();
#       2 _.pie();
#
# AttributeError: 'QgridWidget' object has no attribute 'pie'

# %% [markdown]
# # Show last results

# %%
_
# Out:
# [<kql.kusto_proxy.KustoRow at 0x2037f79acc0>,
#  <kql.kusto_proxy.KustoRow at 0x2037f79ac88>,
#  <kql.kusto_proxy.KustoRow at 0x2037d667cf8>,
#  <kql.kusto_proxy.KustoRow at 0x2037d667ba8>,
#  <kql.kusto_proxy.KustoRow at 0x2037d667c88>,
#  <kql.kusto_proxy.KustoRow at 0x2037d667be0>,
#  <kql.kusto_proxy.KustoRow at 0x2037d667e10>]

# %% [markdown]
# # Kql - render barchart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# | sort by count_
# | limit 10
# | extend cs = 2 * count_
# | render barchart kind=stacked title="Michael's chart";
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:02.035): 10 records

# %%
print("aaa")
# %kql PageViews | summarize count() by Language | sort by count_ | limit 10 | extend cs = 2 * count_ | render barchart kind=stacked title="Michael's chart";
# %kql PageViews | summarize count() by Language | sort by count_ | limit 10 | extend cs = 2 * count_ | render barchart kind=stacked title="Michael's chart";
# Out:
# aaa
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:02.139): 10 records
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:02.156): 10 records

# %% [markdown]
# # Kql - render columnchart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# | sort by count_
# | limit 10
# | extend cs = 2 * count_
# //| extend cs3 = 0.6 * count_
# | render columnchart kind=stacked title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:02.062): 10 records

# %% [markdown]
# # Kql - render linechart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# //| sort by count_
# | limit 10
# | extend cs2 = 2 * count_
# | extend cs3 = 3 * count_
# //| extend cs4 = 4 * count_
# //| extend cs5 = count_ * count_
# | render linechart title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:02.048): 10 records
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="a092d938-efe3-4229-b8dc-0770807f10c7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a092d938-efe3-4229-b8dc-0770807f10c7", [{"type": "scatter", "x": [36, 54276, 95190, 347922, 507336, 1048386, 2804334, 14641824, 15137646, 16266774], "y": [72, 108552, 190380, 695844, 1014672, 2096772, 5608668, 29283648, 30275292, 32533548], "name": "cs2", "line": {"width": 1, "color": "rgb(184, 247, 212)"}, "opacity": 0.8}, {"type": "scatter", "x": [36, 54276, 95190, 347922, 507336, 1048386, 2804334, 14641824, 15137646, 16266774], "y": [108, 162828, 285570, 1043766, 1522008, 3145158, 8413002, 43925472, 45412938, 48800322], "name": "cs3", "line": {"width": 1, "color": "rgb(111, 231, 219)"}, "opacity": 0.8}], {"title": "Michael's chart", "showlegend": true, "xaxis": {"title": "count_"}, "yaxis": {"title": "cs2, cs3", "type": "linear"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# %kql PageViews | summarize count() by Language | limit 10 | extend cs2 = 2 * count_ | extend cs3 = 3 * count_ | render linechart title="Michael's chart"
# %kql PageViews | summarize count() by Language | limit 10 | extend cs2 = 2 * count_ | extend cs3 = 3 * count_ | render linechart title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:02.054): 10 records
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="85098c6b-a53a-4406-9b20-d6edd1a45160" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("85098c6b-a53a-4406-9b20-d6edd1a45160", [{"type": "scatter", "x": [36, 54276, 95190, 347922, 507336, 1048386, 2804334, 14641824, 15137646, 16266774], "y": [72, 108552, 190380, 695844, 1014672, 2096772, 5608668, 29283648, 30275292, 32533548], "name": "cs2", "line": {"width": 1, "color": "rgb(184, 247, 212)"}, "opacity": 0.8}, {"type": "scatter", "x": [36, 54276, 95190, 347922, 507336, 1048386, 2804334, 14641824, 15137646, 16266774], "y": [108, 162828, 285570, 1043766, 1522008, 3145158, 8413002, 43925472, 45412938, 48800322], "name": "cs3", "line": {"width": 1, "color": "rgb(111, 231, 219)"}, "opacity": 0.8}], {"title": "Michael's chart", "showlegend": true, "xaxis": {"title": "count_"}, "yaxis": {"title": "cs2, cs3", "type": "linear"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:02.067): 10 records
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="a463318e-e85d-4789-9009-842a92c892ef" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a463318e-e85d-4789-9009-842a92c892ef", [{"type": "scatter", "x": [36, 54276, 95190, 347922, 507336, 1048386, 2804334, 14641824, 15137646, 16266774], "y": [72, 108552, 190380, 695844, 1014672, 2096772, 5608668, 29283648, 30275292, 32533548], "name": "cs2", "line": {"width": 1, "color": "rgb(184, 247, 212)"}, "opacity": 0.8}, {"type": "scatter", "x": [36, 54276, 95190, 347922, 507336, 1048386, 2804334, 14641824, 15137646, 16266774], "y": [108, 162828, 285570, 1043766, 1522008, 3145158, 8413002, 43925472, 45412938, 48800322], "name": "cs3", "line": {"width": 1, "color": "rgb(111, 231, 219)"}, "opacity": 0.8}], {"title": "Michael's chart", "showlegend": true, "xaxis": {"title": "count_"}, "yaxis": {"title": "cs2, cs3", "type": "linear"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# # Kql - render areachart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# //| sort by count_
# | limit 10
# | extend cs5 = 5 * count_
# | extend cs4 = 4 * count_
# | extend cs3 = 3 * count_
# | extend cs2 = 2 * count_
# | render areachart title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:02.146): 10 records
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="78b5b681-f44c-4ba7-bf6a-88b073b580fa" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("78b5b681-f44c-4ba7-bf6a-88b073b580fa", [{"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [15137646, 14641824, 507336, 2804334, 1048386, 16266774, 95190, 347922, 36, 54276], "name": "count_", "mode": "lines", "line": {"width": 0.5, "color": "rgb(184, 247, 212)"}, "fill": "tozerox"}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [75688230, 73209120, 2536680, 14021670, 5241930, 81333870, 475950, 1739610, 180, 271380], "name": "cs5", "mode": "lines", "line": {"width": 0.5, "color": "rgb(111, 231, 219)"}, "fill": "tozerox"}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [60550584, 58567296, 2029344, 11217336, 4193544, 65067096, 380760, 1391688, 144, 217104], "name": "cs4", "mode": "lines", "line": {"width": 0.5, "color": "rgb(127, 166, 238)"}, "fill": "tozerox"}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [45412938, 43925472, 1522008, 8413002, 3145158, 48800322, 285570, 1043766, 108, 162828], "name": "cs3", "mode": "lines", "line": {"width": 0.5, "color": "rgb(131, 90, 241)"}, "fill": "tozerox"}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [30275292, 29283648, 1014672, 5608668, 2096772, 32533548, 190380, 695844, 72, 108552], "name": "cs2", "mode": "lines", "line": {"width": 0.5, "color": "rgb(184, 247, 212)"}, "fill": "tozerox"}], {"title": "Michael's chart", "showlegend": true, "xaxis": {"title": "Language", "type": "category"}, "yaxis": {"title": "count_, cs5, cs4, cs3, cs2", "type": "linear", "ticksuffix": ""}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# # Kql - render scatterchart

# %%
# %%kql
# PageViews
# | summarize count() by Language
# //| sort by count_
# | limit 10
# | extend cs5 = count_ * 5
# | extend cs4 = count_ * 4
# | extend cs3 = count_ * 3
# | extend cs2 = count_ * 2
# | render scatterchart title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:02.088): 10 records
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="f6ba5078-8c3d-4a8f-88c4-eacbd4077f9a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f6ba5078-8c3d-4a8f-88c4-eacbd4077f9a", [{"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [15137646, 14641824, 507336, 2804334, 1048386, 16266774, 95190, 347922, 36, 54276], "name": "count_", "mode": "markers", "marker": {"line": {"width": 1}, "color": "rgb(184, 247, 212)"}}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [75688230, 73209120, 2536680, 14021670, 5241930, 81333870, 475950, 1739610, 180, 271380], "name": "cs5", "mode": "markers", "marker": {"line": {"width": 1}, "color": "rgb(111, 231, 219)"}}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [60550584, 58567296, 2029344, 11217336, 4193544, 65067096, 380760, 1391688, 144, 217104], "name": "cs4", "mode": "markers", "marker": {"line": {"width": 1}, "color": "rgb(127, 166, 238)"}}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [45412938, 43925472, 1522008, 8413002, 3145158, 48800322, 285570, 1043766, 108, 162828], "name": "cs3", "mode": "markers", "marker": {"line": {"width": 1}, "color": "rgb(131, 90, 241)"}}, {"type": "scatter", "x": ["commons.m", "de", "el", "cs", "ca", "en", "de.b", "de.d", "de.mw", "de.n"], "y": [30275292, 29283648, 1014672, 5608668, 2096772, 32533548, 190380, 695844, 72, 108552], "name": "cs2", "mode": "markers", "marker": {"line": {"width": 1}, "color": "rgb(184, 247, 212)"}}], {"title": "Michael's chart", "showlegend": true, "xaxis": {"title": "Language", "type": "category"}, "yaxis": {"title": "count_, cs5, cs4, cs3, cs2", "type": "linear", "ticksuffix": ""}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# # Kql - render scatterchart

# %%
# %%kql
# let randn = () {rand() + rand() + rand() + rand() + rand() + rand() + rand() + rand() + rand() + rand() + rand() + rand() + rand() + rand()};
# range c from 1 to 1000 step 1
# | limit 1000
# | extend e1 = randn()
# | extend e2 = randn()
# | extend e3 = randn()
# | extend e4 = randn()
# | extend e5 = randn()
# | project e1,e2,e3,e4,e5
# | render scatterchart title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:01.441): 1000 records
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="d8d48e85-53a1-47b8-a402-0713a7714c6a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("
3506817896354604, 1.3526279539849715, 1.3614392721960087, 1.3753079309659628, 1.3765633831166784, 1.37937026661138, 1.3879408918119176, 1.3971655067600544, 1.4037601856678854, 1.409525736673606, 1.4129552373290146, 1.4138361920278868, 1.4143485058976895, 1.4144236495681066, 1.420961962360017, 1.4210942341272448, 1.4237082629516764, 1.4264986659270806, 1.4307310674607936, 1.440996423386486, 1.444055666991952, 1.4443813302710253, 1.46560146155428, 1.4663162799771945, 1.4669981250793311, 1.4673480004049055, 1.471548511610306, 1.475480446760745, 1.4829620191991313, 1.4860582275232286, 1.4948030258058904, 1.504153 ...

# %% [markdown]
# # Kql - render anomalychart

# %%
# %%kql
# let randn = () {rand() + rand() + rand()};
# range columnName from datetime('2015-01-01') to datetime('2016-01-10') step timespan('1d')
# | extend e1 = randn()
# | extend e2 = randn()
# | extend e3 = randn()
# | extend e4 = randn()
# | render anomalychart title="Michael's chart"
# Out:
#    OperationInsights_PFS_PROD@Oiildc
#  * Samples@help
# Done (00:01.055): 375 records
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="6ab8dd8e-f90e-4085-9353-6a641501fa51" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6ab8dd8e-f90e-4085-9353-6a641501fa51", [{"type": "scatter", "x": ["2015-01-01", "2015-01-02", "2015-01-03", "2015-01-04", "2015-01-05", "2015-01-06", "2015-01-07", "2015-01-08", "2015-01-09", "2015-01-10", "2015-01-11", "2015-01-12", "2015-01-13", "2015-01-14", "2015-01-15", "2015-01-16", "2015-01-17", "2015-01-18", "2015-01-19", "2015-01-20", "2015-01-21", "2015-01-22", "2015-01-23", "2015-01-24", "2015-01-25", "2015-01-26", "2015-01-27", "2015-01-28", "2015-01-29", "2015-01-30", "2015-01-31", "2015-02-01", "2015-02-02", "2015-02-03", "2015-02-04", "2015-02-05", "2015-02-06", "2015-02-07", "2015-02-08", "2015-02-09", "2015-02-10", "2015-02-11", "2015-02-12", "2015-02-13", "2015-02-14", "2015-02-15", "2015-02-16", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-21", "2015-02-22", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-02-28", "2015-03-01", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-07", "2015-03-08", "2015-03-09", "2015-03-10", "2015-03-11", "2015-03-12", "2015-03-13", "2015-03-14", "2015-03-15", "2015-03-16", "2015-03-17", "2015-03-18", "2015-03-19", "2015-03-20", "2015-03-21", "2015-03-22", "2015-03-23", "2015-03-24", "2015-03-25", "2015-03-26", "2015-03-27", "2015-03-28", "2015-03-29", "2015-03-30", "2015-03-31", "2015-04-01", "2015-04-02", "2015-04-03", "2015-04-04", "2015-04-05", "2015-04-06", "2015-04-07", "2015-04-08", "2015-04-09", "2015-04-10", "2015-04-11", "2015-04-12", "2015-04-13", "2015-04-14", "2015-04-15", "2015-04-16", "2015-04-17", "2015-04-18", "2015-04-19", "2015-04-20", "2015-04-21", "2015-04-22", "2015-04-23", "2015-04-24", "2015-04-25", "2015-04-26", "2015-04-27", "2015-04-28", "2015-04-29", "2015-04-30", "2015-05-01", "2015-05-02", "2015-05-03", "2015-05-04", "2015-05-05", "2015-05-06", "2015-05-07", "2015-05-08", "2015-05-09", "2015-05-10", "2015-05-11", "2015-05-12", "2015-05-13", "2015-05-14", "2015-05-15", "2015-05-16", "2015-05-17", "2015-05-18", "2015-05-19", "2015-05-20", "2015-05-21", "2015-05-22", "2015-05-23", "2015-05-24", "2015-05-25", "2015-05-26", "2015-05-27", "2015-05-28", "2015-05-29", "2015-05-30", "2015-05-31", "2015-06-01", "2015-06-02", "2015-06-03", "2015-06-04", "2015-06-05", "2015-06-06", "2015-06-07", "2015-06-08", "2015-06-09", "2015-06-10", "2015-06-11", "2015-06-12", "2015-06-13", "2015-06-14", "2015-06-15", "2015-06-16", "2015-06-17", "2015-06-18", "2015-06-19", "2015-06-20", "2015-06-21", "2015-06-22", "2015-06-23", "2015-06-24", "2015-06-25", "2015-06-26", "2015-06-27", "2015-06-28", "2015-06-29", "2015-06-30", "2015-07-01", "2015-07-02", "2015-07-03", "2015-07-04", "2015-07-05", "2015-07-06", "2015-07-07", "2015-07-08", "2015-07-09", "2015-07-10", "2015-07-11", "2015-07-12", "2015-07-13", "2015-07-14", "2015-07-15", "2015-07-16", "2015-07-17", "2015-07-18", "2015-07-19", "2015-07-20", "2015-07-21", "2015-07-22", "2015-07-23", "2015-07-24", "2015-07-25", "2015-07-26", "2015-07-27", "2015-07-28", "2015-07-29", "2015-07-30", "2015-07-31", "2015-08-01", "2015-08-02", "2015-08-03", "2015-08-04", "2015-08-05", "2015-08-06", "2015-08-07", "2015-08-08", "2015-08-09", "2015-08-10", "2015-08-11", "2015-08-12", "2015-08-13", "2015-08-14", "2015-08-15", "2015-08-16", "2015-08-17", "2015-08-18", "2015-08-19", "2015-08-20", "2015-08-21", "2015-08-22", "2015-08-23", "2015-08-24", "2015-08-25", "2015-08-26", "2015-08-27", "2015-08-28", "2015-08-29", "2015-08-30", "2015-08-31", "2015-09-01", "2015-09-02", "2015-09-03", "2015-09-04", "2015-09-05", "2015-09-06", "2015-09-07", "2015-09-08", "2015-09-09", "2015-09-10", "2015-09-11", "2015-09-12", "2015-09-13", "2015-09-14", "2015-09-15", "2015-09-16", "2015-09-17", "2015-09-1 ...

# %%
name = input("what is your name: ")
print("name: ", name)
name = input("what is your name: ")
print("name: ", name)
name = input("what is your name: ")
print("name: ", name)
# Out:
# what is your name:
# name:
# what is your name:
# name:
# what is your name:
# name:

# %%
import getpass
p = getpass.getpass()
# Out:
# ········

# %%
print(p)

# %%
import ipywidgets as widgets
from IPython.display import display
w = widgets.IntSlider(12)
display(w)
# Out:
# IntSlider(value=12)

# %%
display(w)
display(w)
display(w)
# Out:
# IntSlider(value=12)
# IntSlider(value=12)
# IntSlider(value=12)

# %%
w.value
# Out:
# 12

# %%
p = getpass.getpass()
p = getpass.getpass()
p = getpass.getpass()
# Out:
# ········
# ········
# ········

# %%
# %pushd
# %cd C:\My Projects\KqlMagic\src
# %load_ext kql
# %popd
# Out:
# C:\My Projects\KqlMagic\src
# The kql extension is already loaded. To reload it, use:
#   %reload_ext kql
# c:\My Projects\KqlMagic\notebooks
# popd -> c:\My Projects\KqlMagic\notebooks

# %%
# %kql appinsights://appid('DEMO_APP').appkey('DEMO_KEY')
# Out:
# 'Connected: DEMO_APP@appinsights'

# %%
# %kql appinsights:/
# Out:
#  * DEMO_APP@appinsights
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@help
# ['{"error":{"message":"The request had some invalid properties","code":"BadArgumentError","innererror":{"code":"SyntaxError","message":"A recognition error occurred in the query.","innererror":{"code":"SYN0002","message":"Query could not be parsed at \'/\' on line [1,12]","line":1,"pos":12,"token":"/"}}}}']

# %%
# %%kql
# let randn = () {rand() + rand() + rand()};
# range columnName from datetime('2015-01-01') to datetime('2016-01-10') step timespan('1d')
# | extend e1 = randn()
# | extend e2 = randn()
# | extend e3 = randn()
# | extend e4 = randn()
# | render anomalychart title="Michael's chart"
# Out:
#  * DEMO_APP@appinsights
#    OperationInsights_PFS_PROD@Oiildc
#    Samples@help
# Done (00:00.901): 375 records
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="7ce59dc7-7532-40ce-9b8d-9ad228a671a8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7ce59dc7-7532-40ce-9b8d-9ad228a671a8", [{"type": "scatter", "x": ["2015-01-01", "2015-01-02", "2015-01-03", "2015-01-04", "2015-01-05", "2015-01-06", "2015-01-07", "2015-01-08", "2015-01-09", "2015-01-10", "2015-01-11", "2015-01-12", "2015-01-13", "2015-01-14", "2015-01-15", "2015-01-16", "2015-01-17", "2015-01-18", "2015-01-19", "2015-01-20", "2015-01-21", "2015-01-22", "2015-01-23", "2015-01-24", "2015-01-25", "2015-01-26", "2015-01-27", "2015-01-28", "2015-01-29", "2015-01-30", "2015-01-31", "2015-02-01", "2015-02-02", "2015-02-03", "2015-02-04", "2015-02-05", "2015-02-06", "2015-02-07", "2015-02-08", "2015-02-09", "2015-02-10", "2015-02-11", "2015-02-12", "2015-02-13", "2015-02-14", "2015-02-15", "2015-02-16", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-21", "2015-02-22", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-02-28", "2015-03-01", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-07", "2015-03-08", "2015-03-09", "2015-03-10", "2015-03-11", "2015-03-12", "2015-03-13", "2015-03-14", "2015-03-15", "2015-03-16", "2015-03-17", "2015-03-18", "2015-03-19", "2015-03-20", "2015-03-21", "2015-03-22", "2015-03-23", "2015-03-24", "2015-03-25", "2015-03-26", "2015-03-27", "2015-03-28", "2015-03-29", "2015-03-30", "2015-03-31", "2015-04-01", "2015-04-02", "2015-04-03", "2015-04-04", "2015-04-05", "2015-04-06", "2015-04-07", "2015-04-08", "2015-04-09", "2015-04-10", "2015-04-11", "2015-04-12", "2015-04-13", "2015-04-14", "2015-04-15", "2015-04-16", "2015-04-17", "2015-04-18", "2015-04-19", "2015-04-20", "2015-04-21", "2015-04-22", "2015-04-23", "2015-04-24", "2015-04-25", "2015-04-26", "2015-04-27", "2015-04-28", "2015-04-29", "2015-04-30", "2015-05-01", "2015-05-02", "2015-05-03", "2015-05-04", "2015-05-05", "2015-05-06", "2015-05-07", "2015-05-08", "2015-05-09", "2015-05-10", "2015-05-11", "2015-05-12", "2015-05-13", "2015-05-14", "2015-05-15", "2015-05-16", "2015-05-17", "2015-05-18", "2015-05-19", "2015-05-20", "2015-05-21", "2015-05-22", "2015-05-23", "2015-05-24", "2015-05-25", "2015-05-26", "2015-05-27", "2015-05-28", "2015-05-29", "2015-05-30", "2015-05-31", "2015-06-01", "2015-06-02", "2015-06-03", "2015-06-04", "2015-06-05", "2015-06-06", "2015-06-07", "2015-06-08", "2015-06-09", "2015-06-10", "2015-06-11", "2015-06-12", "2015-06-13", "2015-06-14", "2015-06-15", "2015-06-16", "2015-06-17", "2015-06-18", "2015-06-19", "2015-06-20", "2015-06-21", "2015-06-22", "2015-06-23", "2015-06-24", "2015-06-25", "2015-06-26", "2015-06-27", "2015-06-28", "2015-06-29", "2015-06-30", "2015-07-01", "2015-07-02", "2015-07-03", "2015-07-04", "2015-07-05", "2015-07-06", "2015-07-07", "2015-07-08", "2015-07-09", "2015-07-10", "2015-07-11", "2015-07-12", "2015-07-13", "2015-07-14", "2015-07-15", "2015-07-16", "2015-07-17", "2015-07-18", "2015-07-19", "2015-07-20", "2015-07-21", "2015-07-22", "2015-07-23", "2015-07-24", "2015-07-25", "2015-07-26", "2015-07-27", "2015-07-28", "2015-07-29", "2015-07-30", "2015-07-31", "2015-08-01", "2015-08-02", "2015-08-03", "2015-08-04", "2015-08-05", "2015-08-06", "2015-08-07", "2015-08-08", "2015-08-09", "2015-08-10", "2015-08-11", "2015-08-12", "2015-08-13", "2015-08-14", "2015-08-15", "2015-08-16", "2015-08-17", "2015-08-18", "2015-08-19", "2015-08-20", "2015-08-21", "2015-08-22", "2015-08-23", "2015-08-24", "2015-08-25", "2015-08-26", "2015-08-27", "2015-08-28", "2015-08-29", "2015-08-30", "2015-08-31", "2015-09-01", "2015-09-02", "2015-09-03", "2015-09-04", "2015-09-05", "2015-09-06", "2015-09-07", "2015-09-08", "2015-09-09", "2015-09-10", "2015-09-11", "2015-09-12", "2015-09-13", "2015-09-14", "2015-09-15", "2015-09-16", "2015-09-17", "2015-09-1 ...
